# %%
import torch                                                  #tensor related operations
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torchvision.datasets import CIFAR100
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from torch.distributions import Gumbel

# %matplotlib inline

# %%
dataset = CIFAR100(root = 'data/', download = True, transform = ToTensor())
test_dataset = CIFAR100(root = 'data/', train = False, transform = ToTensor())
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to data/cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [00:14<00:00, 11559436.62it/s]
# Extracting data/cifar-100-python.tar.gz to data/

# %%
print(len(dataset))
print(len(test_dataset))
# Out:
# 50000
# 10000

# %%
classes = dataset.classes 
print('Number of Classes:', len(classes))
print('Class Names :\n', classes)
# Out:
# Number of Classes: 100
# Class Names :
#  ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# %%
img, label = dataset[31]
img_shape = img.shape

# %%
img, label = dataset[31]
plt.imshow(img.permute((1,2,0)))
print('Label as Number:', label)
print('Label as Name:', classes[label])
# Out:
# Label as Number: 17
# Label as Name: castle

# %%
torch.manual_seed(43)
val_size = 10000
train_size = len(dataset) - val_size

# %%
# Random Split and Split of dataset between train and validation.
train_ds, val_ds = random_split(dataset,[train_size, val_size])
len(train_ds), len(val_ds)
# Out:
# (40000, 10000)

# %%
batch_size = 128

# %%
test_loader = DataLoader(test_dataset, batch_size, num_workers=4, pin_memory =True)
train_loader = DataLoader(train_ds, batch_size, shuffle = True, num_workers=4, pin_memory =True)
val_loader = DataLoader(val_ds, batch_size, num_workers=4, pin_memory =True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
for images, _ in train_loader: 
    print('Shape of an Image (Batch Size, RGB, Pixels):', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1,2,0))) 
    break
# Out:
# Shape of an Image (Batch Size, RGB, Pixels): torch.Size([128, 3, 32, 32])

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
device = get_default_device()

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
import torch.nn.functional as F


class log_taylor_softmax(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input):
        #print(input)
      
        #i = 1 + input + 0.5*input*input
        #n = torch.add(torch.add(input, 1), torch.mul(, 0.5))
        n = 1 + input + 0.5*torch.pow(input, 2)
        logits = torch.div(n,float(torch.sum(n)))
        return torch.log(logits)

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1), 
              nn.BatchNorm2d(out_channels), 
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(ImageClassificationBase):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        
        self.conv1 = conv_block(in_channels, 64)
        self.conv2 = conv_block(64, 128, pool=True)
        self.res1 = nn.Sequential(conv_block(128, 128), conv_block(128, 128))
        
        self.conv3 = conv_block(128, 256, pool=True)
        self.conv4 = conv_block(256, 512, pool=True)
        self.res2 = nn.Sequential(conv_block(512, 512), conv_block(512, 512))
        
        self.classifier = nn.Sequential(nn.MaxPool2d(4), 
                                        nn.Flatten(),
                                        nn.Dropout(0.25), 
                                        nn.Linear(512, num_classes),
                                        log_taylor_softmax())
    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out) 
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit_one_cycle(epochs, max_lr, model, train_loader, val_loader, 
                  weight_decay=0, grad_clip=None, opt_func=torch.optim.SGD):
    torch.cuda.empty_cache()
    history = []
    
    # Set up cutom optimizer with weight decay
    optimizer = opt_func(model.parameters(), max_lr, weight_decay=weight_decay)
    # Set up one-cycle learning rate scheduler
    sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epochs, 
                                                steps_per_epoch=len(train_loader))
    
    for epoch in range(epochs):
        # Training Phase 
        model.train()
        train_losses = []
        lrs = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            
            # Gradient clipping
            if grad_clip: 
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            # Record & update learning rate
            lrs.append(get_lr(optimizer))
            sched.step()
        
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        result['lrs'] = lrs
        model.epoch_end(epoch, result)
        history.append(result)


    model.eval()
    predicted = list()
    actual = list()
    for batch in val_loader:
        outputs = model(batch[0])
        predicted.extend(torch.argmax(outputs, dim=1).tolist())
        actual.extend(batch[1].tolist())

    conf_mat = confusion_matrix(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    F1 = f1_score(actual, predicted, average='macro')
    
    val = [conf_mat,precision,recall,F1]
    key = ['conf_mat','precision','recall','F1']

    for i in range(0,4):
      history[-1][key[i]] = val[i]
    
    return history

# %%
from torchvision import models
from torchsummary import summary
model_resnet9 = to_device(ResNet9(3, 100), device)
summary(model_resnet9, input_size = (3, 32, 32), batch_size = 128)
model_resnet9
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [128, 64, 32, 32]           1,792
#        BatchNorm2d-2          [128, 64, 32, 32]             128
#               ReLU-3          [128, 64, 32, 32]               0
#             Conv2d-4         [128, 128, 32, 32]          73,856
#        BatchNorm2d-5         [128, 128, 32, 32]             256
#               ReLU-6         [128, 128, 32, 32]               0
#          MaxPool2d-7         [128, 128, 16, 16]               0
#             Conv2d-8         [128, 128, 16, 16]         147,584
#        BatchNorm2d-9         [128, 128, 16, 16]             256
#              ReLU-10         [128, 128, 16, 16]               0
#            Conv2d-11         [128, 128, 16, 16]         147,584
#       BatchNorm2d-12         [128, 128, 16, 16]             256
#              ReLU-13         [128, 128, 16, 16]               0
#            Conv2d-14         [128, 256, 16, 16]         295,168
#       BatchNorm2d-15         [128, 256, 16, 16]             512
#              ReLU-16         [128, 256, 16, 16]               0
#         MaxPool2d-17           [128, 256, 8, 8]               0
#            Conv2d-18           [128, 512, 8, 8]       1,180,160
#       BatchNorm2d-19           [128, 512, 8, 8]           1,024
#              ReLU-20           [128, 512, 8, 8]               0
#         MaxPool2d-21           [128, 512, 4, 4]               0
#            Conv2d-22           [128, 512, 4, 4]       2,359,808
#       BatchNorm2d-23           [128, 512, 4, 4]           1,024
#              ReLU-24           [128, 512, 4, 4]               0
#            Conv2d-25           [128, 512, 4, 4]       2,359,808
#       BatchNorm2d-26           [128, 512, 4, 4]           1,024
#              ReLU-27           [128, 512, 4, 4]               0
#         MaxPool2d-28           [128, 512, 1, 1]               0
#           Flatten-29                 [128, 512]               0
#           Dropout-30                 [128, 512]               0
#            Linear-31                 [128, 100]          51,300
# log_taylor_softmax-32                 [128, 100]               0
# ================================================================
# Total params: 6,621,540
# Trainable params: 6,621,540
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.50
# Forward/backward pass size (MB): 1161.70
# Params size (MB): 25.26
# Estimated Total Size (MB): 1188.45
# ----------------------------------------------------------------
# ResNet9(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (res2): Sequential(
#     (0): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=512, out_features=100, bias=True)
#     (4): log_taylor_softmax()
#   )
# )

# %%
history_resnet9 = [evaluate(model_resnet9, val_loader)]
history_resnet9
# Out:
# [{'val_loss': 4.606239318847656, 'val_acc': 0.010087025351822376}]

# %%
no_of_epochs = 100
max_learn_r = 0.01
grad_clip = 0.1
weight_decay = 1e-4
optim_func = torch.optim.Adam

# %%
# %%time
history_resnet9 += fit_one_cycle(no_of_epochs, max_learn_r, model_resnet9, train_loader, val_loader, 
                             grad_clip=grad_clip, 
                             weight_decay=weight_decay,  
                             opt_func=optim_func)
# Out:
# Epoch [0], last_lr: 0.00043, train_loss: 3.9363, val_loss: 3.4666, val_acc: 0.1857
# Epoch [1], last_lr: 0.00050, train_loss: 3.2554, val_loss: 3.0386, val_acc: 0.2765
# Epoch [2], last_lr: 0.00063, train_loss: 2.8331, val_loss: 2.6906, val_acc: 0.3722
# Epoch [3], last_lr: 0.00081, train_loss: 2.5285, val_loss: 2.5450, val_acc: 0.3931
# Epoch [4], last_lr: 0.00104, train_loss: 2.2891, val_loss: 2.4729, val_acc: 0.4026
# Epoch [5], last_lr: 0.00132, train_loss: 2.0959, val_loss: 2.2250, val_acc: 0.4571
# Epoch [6], last_lr: 0.00163, train_loss: 1.8999, val_loss: 2.2647, val_acc: 0.4395
# Epoch [7], last_lr: 0.00199, train_loss: 1.7255, val_loss: 2.3227, val_acc: 0.4220
# Epoch [8], last_lr: 0.00238, train_loss: 1.5682, val_loss: 1.9980, val_acc: 0.4831
# Epoch [9], last_lr: 0.00280, train_loss: 1.4474, val_loss: 2.0825, val_acc: 0.4896
# Epoch [10], last_lr: 0.00325, train_loss: 1.3350, val_loss: 2.3190, val_acc: 0.4281
# Epoch [11], last_lr: 0.00372, train_loss: 1.2744, val_loss: 2.2564, val_acc: 0.4541
# Epoch [12], last_lr: 0.00420, train_loss: 1.2839, val_loss: 2.1482, val_acc: 0.4773
# Epoch [13], last_lr: 0.00470, train_loss: 1.2825, val_loss: 2.2311, val_acc: 0.4623
# Epoch [14], last_lr: 0.00520, train_loss: 1.2807, val_loss: 2.6268, val_acc: 0.3907
# Epoch [15], last_lr: 0.00570, train_loss: 1.4318, val_loss: 2.1976, val_acc: 0.4763
# Epoch [16], last_lr: 0.00620, train_loss: 1.4643, val_loss: 2.7204, val_acc: 0.3721
# Epoch [17], last_lr: 0.00668, train_loss: 1.6153, val_loss: 2.3879, val_acc: 0.4179
# Epoch [18], last_lr: 0.00715, train_loss: 1.6369, val_loss: 2.4351, val_acc: 0.4290
# Epoch [19], last_lr: 0.00760, train_loss: 1.7281, val_loss: 2.3470, val_acc: 0.4353
# Epoch [20], last_lr: 0.00802, train_loss: 1.7677, val_loss: 2.3465, val_acc: 0.4316
# Epoch [21], last_lr: 0.00841, train_loss: 1.8352, val_loss: 2.3028, val_acc: 0.4353
# Epoch [22], last_lr: 0.00877, train_loss: 1.8691, val_loss: 2.4208, val_acc: 0.4170
# Epoch [23], last_lr: 0.00908, train_loss: 1.8668, val_loss: 2.3655, val_acc: 0.4152
# Epoch [24], last_lr: 0.00936, train_loss: 1.8941, val_loss: 2.1848, val_acc: 0.4386
# Epoch [25], last_lr: 0.00958, train_loss: 1.9118, val_loss: 2.5604, val_acc: 0.3777
# Epoch [26], last_lr: 0.00977, train_loss: 1.9100, val_loss: 2.5047, val_acc: 0.3879
# Epoch [27], last_lr: 0.00990, train_loss: 1.9290, val_loss: 2.3859, val_acc: 0.4151
# Epoch [28], last_lr: 0.00997, train_loss: 1.9305, val_loss: 2.4162, val_acc: 0.4062
# Epoch [29], last_lr: 0.01000, train_loss: 1.9360, val_loss: 2.4737, val_acc: 0.3927
# Epoch [30], last_lr: 0.00999, train_loss: 1.9350, val_loss: 2.7971, val_acc: 0.3202
# Epoch [31], last_lr: 0.00998, train_loss: 1.9377, val_loss: 2.3377, val_acc: 0.3963
# Epoch [32], last_lr: 0.00995, train_loss: 1.9177, val_loss: 2.5839, val_acc: 0.3675
# Epoch [33], last_lr: 0.00992, train_loss: 1.9165, val_loss: 2.5445, val_acc: 0.3744
# Epoch [34], last_lr: 0.00987, train_loss: 1.9126, val_loss: 2.2130, val_acc: 0.4359
# Epoch [35], last_lr: 0.00982, train_loss: 1.9027, val_loss: 2.3993, val_acc: 0.3937
# Epoch [36], last_lr: 0.00976, train_loss: 1.8986, val_loss: 2.6525, val_acc: 0.3404
# Epoch [37], last_lr: 0.00968, train_loss: 1.9087, val_loss: 2.2032, val_acc: 0.4297
# Epoch [38], last_lr: 0.00960, train_loss: 1.8813, val_loss: 2.3826, val_acc: 0.3981
# Epoch [39], last_lr: 0.00950, train_loss: 1.8682, val_loss: 2.3214, val_acc: 0.4057
# Epoch [40], last_lr: 0.00940, train_loss: 1.8695, val_loss: 2.2191, val_acc: 0.4351
# Epoch [41], last_lr: 0.00929, train_loss: 1.8493, val_loss: 2.3366, val_acc: 0.3952
# Epoch [42], last_lr: 0.00917, train_loss: 1.8537, val_loss: 2.5743, val_acc: 0.3645
# Epoch [43], last_lr: 0.00905, train_loss: 1.8338, val_loss: 2.5422, val_acc: 0.3601
# Epoch [44], last_lr: 0.00891, train_loss: 1.8141, val_loss: 2.4511, val_acc: 0.3758
# Epoch [45], last_lr: 0.00877, train_loss: 1.8187, val_loss: 2.4529, val_acc: 0.3808
# Epoch [46], last_lr: 0.00861, train_loss: 1.7708, val_loss: 2.4464, val_acc: 0.3810
# Epoch [47], last_lr: 0.00846, train_loss: 1.7809, val_loss: 2.2489, val_acc: 0.4155
# Epoch [48], last_lr: 0.00829, train_loss: 1.7541, val_loss: 2.2637, val_acc: 0.4183
# Epoch [49], last_lr: 0.00812, train_loss: 1.7296, val_loss: 2.4697, val_acc: 0.3876
# Epoch [50], last_lr: 0.00794, train_loss: 1.7009, val_loss: 2.1816, val_acc: 0.4437
# Epoch [51], last_lr: 0.00775, train_loss: 1.6647, val_loss: 2.2694, val_acc: 0.4366
# Epoch [52], last_lr: 0.00756, train_loss: 1.6512, val_loss: 2.1976, val_acc: 0.4245
# Epoch [53], last_lr: 0.00737, train_loss: 1.6334, val_loss: 2.2040, val_acc: 0.4297
# Epoch [54], last_lr: 0.00717, train_loss: 1.6320, val_loss: 2.3289, val_acc: 0.4070
# Epoch [55], last_lr: 0.00697, train_loss: 1.5988, val_loss: 2.3642, val_acc: 0.4062
# Epoch [56], last_lr: 0.00676, train_loss: 1.5732, val_loss: 2.1527, val_acc: 0.4436
# Epoch [57], last_lr: 0.00655, train_loss: 1.5623, val_loss: 2.5385, val_acc: 0.3967
# Epoch [58], last_lr: 0.00633, train_loss: 1.5367, val_loss: 2.1643, val_acc: 0.4482
# Epoch [59], last_lr: 0.00611, train_loss: 1.5071, val_loss: 2.5864, val_acc: 0.3985
# Epoch [60], last_lr: 0.00589, train_loss: 1.4813, val_loss: 2.1646, val_acc: 0.4473
# Epoch [61], last_lr: 0.00567, train_loss: 1.4529, val_loss: 2.1039, val_acc: 0.4504
# Epoch [62], last_lr: 0.00545, train_loss: 1.4018, val_loss: 2.1862, val_acc: 0.4441
# Epoch [63], last_lr: 0.00522, train_loss: 1.3707, val_loss: 2.1243, val_acc: 0.4539
# Epoch [64], last_lr: 0.00500, train_loss: 1.3640, val_loss: 2.2023, val_acc: 0.4541
# Epoch [65], last_lr: 0.00478, train_loss: 1.3296, val_loss: 2.2315, val_acc: 0.4426
# Epoch [66], last_lr: 0.00455, train_loss: 1.2960, val_loss: 2.4293, val_acc: 0.4105
# Epoch [67], last_lr: 0.00433, train_loss: 1.2797, val_loss: 2.1548, val_acc: 0.4583
# Epoch [68], last_lr: 0.00411, train_loss: 1.2596, val_loss: 2.1679, val_acc: 0.4524
# Epoch [69], last_lr: 0.00389, train_loss: 1.1831, val_loss: 2.2030, val_acc: 0.4509
# Epoch [70], last_lr: 0.00367, train_loss: 1.1513, val_loss: 2.1529, val_acc: 0.4629
# Epoch [71], last_lr: 0.00345, train_loss: 1.1220, val_loss: 2.1326, val_acc: 0.4644
# Epoch [72], last_lr: 0.00324, train_loss: 1.0934, val_loss: 2.2676, val_acc: 0.4470
# Epoch [73], last_lr: 0.00303, train_loss: 1.0510, val_loss: 2.1870, val_acc: 0.4635
# Epoch [74], last_lr: 0.00283, train_loss: 1.0442, val_loss: 2.2313, val_acc: 0.4550
# Epoch [75], last_lr: 0.00263, train_loss: 0.9950, val_loss: 2.2033, val_acc: 0.4690
# Epoch [76], last_lr: 0.00244, train_loss: 0.9555, val_loss: 2.2144, val_acc: 0.4630
# Epoch [77], last_lr: 0.00225, train_loss: 0.9165, val_loss: 2.2686, val_acc: 0.4543
# Epoch [78], last_lr: 0.00206, train_loss: 0.8726, val_loss: 2.2974, val_acc: 0.4691
# Epoch [79], last_lr: 0.00188, train_loss: 0.8216, val_loss: 2.2516, val_acc: 0.4682
# Epoch [80], last_lr: 0.00171, train_loss: 0.7850, val_loss: 2.2559, val_acc: 0.4773
# Epoch [81], last_lr: 0.00154, train_loss: 0.7523, val_loss: 2.2770, val_acc: 0.4720
# Epoch [82], last_lr: 0.00139, train_loss: 0.7221, val_loss: 2.2527, val_acc: 0.4760
# Epoch [83], last_lr: 0.00123, train_loss: 0.6934, val_loss: 2.2677, val_acc: 0.4810
# Epoch [84], last_lr: 0.00109, train_loss: 0.6601, val_loss: 2.3237, val_acc: 0.4749
# Epoch [85], last_lr: 0.00095, train_loss: 0.6310, val_loss: 2.3183, val_acc: 0.4801
# Epoch [86], last_lr: 0.00083, train_loss: 0.6093, val_loss: 2.3172, val_acc: 0.4760
# Epoch [87], last_lr: 0.00071, train_loss: 0.5844, val_loss: 2.3375, val_acc: 0.4716
# Epoch [88], last_lr: 0.00060, train_loss: 0.5740, val_loss: 2.3437, val_acc: 0.4770
# Epoch [89], last_lr: 0.00050, train_loss: 0.5623, val_loss: 2.3343, val_acc: 0.4758
# Epoch [90], last_lr: 0.00040, train_loss: 0.5455, val_loss: 2.3410, val_acc: 0.4769
# Epoch [91], last_lr: 0.00032, train_loss: 0.5365, val_loss: 2.3518, val_acc: 0.4747
# Epoch [92], last_lr: 0.00024, train_loss: 0.5313, val_loss: 2.3381, val_acc: 0.4787
# Epoch [93], last_lr: 0.00018, train_loss: 0.5200, val_loss: 2.3438, val_acc: 0.4788
# Epoch [94], last_lr: 0.00013, train_loss: 0.5158, val_loss: 2.3408, val_acc: 0.4774
# Epoch [95], last_lr: 0.00008, train_loss: 0.5114, val_loss: 2.3419, val_acc: 0.4761
# Epoch [96], last_lr: 0.00005, train_loss: 0.5059, val_loss: 2.3488, val_acc: 0.4789
# Epoch [97], last_lr: 0.00002, train_loss: 0.5040, val_loss: 2.3515, val_acc: 0.4785
# Epoch [98], last_lr: 0.00001, train_loss: 0.5032, val_loss: 2.3550, val_acc: 0.4760
# Epoch [99], last_lr: 0.00000, train_loss: 0.5010, val_loss: 2.3444, val_acc: 0.4804
# CPU times: user 27min 57s, sys: 57.2 s, total: 28min 54s
# Wall time: 34min 19s

# %%
last = history_resnet9[len(history_resnet9)-1]
precision = last['precision']
recall = last['recall']
F1 = last['F1']

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {F1:.4f}")
# Out:
# Precision: 0.5107
# Recall: 0.4782
# F1 Score: 0.4760

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(50, 50))
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.plasma)
    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=30)
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=90,fontsize=20)
    plt.yticks(tick_marks, class_names,fontsize=20)
    plt.xlabel('Predicted Label',fontsize=20)
    plt.ylabel('True Label',fontsize=20)
    plt.title('Confusion Matrix',fontsize=20)
    plt.show()

last = history_resnet9[len(history_resnet9)-1]
conf_mat = last['conf_mat']
plot_confusion_matrix(conf_mat, classes)

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-o')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy vs. Number of Epochs');

# %%
plot_accuracies(history_resnet9)

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bo')
    plt.plot(val_losses, '-ro')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. Number of epochs');

# %%
plot_losses(history_resnet9)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch Number')
    plt.ylabel('Learning Rate')
    plt.title('Learning Rate vs. Batch Number');

# %%
plot_lrs(history_resnet9)

# %%
test_resnet9 = evaluate(model_resnet9, test_loader) #final evaluation of resnet9 model with test dataset
test_resnet9
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# {'val_loss': 2.303607225418091, 'val_acc': 0.4918908178806305}

# %%
test_loss_resnet9 = test_resnet9['val_loss']
test_acc_resnet9 = test_resnet9['val_acc']
print('test_loss_resnet9:', test_resnet9['val_loss'])
print('test_acc_resnet9:', test_resnet9['val_acc'])
# Out:
# test_loss_resnet9: 2.303607225418091
# test_acc_resnet9: 0.4918908178806305

# %%
def predict_image(img, model_resnet9):
    xb = to_device(img.unsqueeze(0), device)
    yb = model_resnet9(xb)
    _, preds  = torch.max(yb, dim=1)
    return dataset.classes[preds[0].item()]

# %%
img, label = test_dataset[111]
plt.imshow(img.permute(1, 2, 0))
print('Label:', dataset.classes[label], ', Predicted:', predict_image(img, model_resnet9))
# Out:
# Label: chair , Predicted: chair
